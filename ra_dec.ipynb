# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('my_data.csv')

# %%
df.head()
# Out:
#     77.9979,231.91
# 0   16.4625,303.73
# 1  80.5071,347.326
# 2  87.9965,317.712
# 3    71.21,271.211
# 4  57.4396,339.078

# %%
df = df.rename(columns = {'77.9979': 'Zenith'})

# %%
df.head()
